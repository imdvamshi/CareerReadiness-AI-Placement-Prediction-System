# %%
import pandas as pd
import numpy as np

# %%
import sys
sys.path.append("..")
from src.load_data import load_data
data = load_data()
data.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             72.647009              77.463863         2
# ...

# %% [markdown]
# Removing salary_package_lpa feature because it leaks information. Students who are not placed usually have 0 LPA, making it a target-derived feature.

# %%
data = data.drop(columns=['salary_package_lpa'])
data.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    linkedin_connections  mock_interview_score  attendance_percentage  \
# ...

# %% [markdown]
# Encoding the target value - placement_status using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['placement_status'] = le.fit_transform(data['placement_status'])
data.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    linkedin_connections  mock_interview_score  attendance_percentage  \
# ...

# %%
data.to_csv("../src/afterFeatureEngineering_data.csv",index=False)
