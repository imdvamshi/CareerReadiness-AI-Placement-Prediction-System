# %%
import pandas as pd
import numpy as np

# %%
import joblib

# %%
x_train = pd.read_csv("../src/x_train.csv")
y_train = pd.read_csv("../src/y_train.csv")
y_train = y_train.squeeze()
x_test = pd.read_csv("../src/x_test.csv")
y_test = pd.read_csv("../src/y_test.csv")
y_test = y_test.squeeze()

# %%
x_train.drop(columns=['student_id'],inplace=True)
x_test.drop(columns=['student_id'],inplace=True)

# %% [markdown]
# ColumnTransformer

# %%
# numeric columns 
num_cols = [
    "age","cgpa","internships_count","projects_count",
    "certifications_count","coding_skill_score",
    "aptitude_score","communication_skill_score",
    "logical_reasoning_score","hackathons_participated",
    "github_repos","linkedin_connections",
    "mock_interview_score","attendance_percentage",
    "backlogs","extracurricular_score","leadership_score",
    "sleep_hours","study_hours_per_day"
]

# %%
# text columns for OneHotEncoder
text_cols_onehot = [
    "gender","branch","volunteer_experience"
]

# %%
# text columns for OrdinalEncoder
text_cols_ordinal = ["college_tier"]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
preprocessor = ColumnTransformer(transformers=[
    ('ohe',OneHotEncoder(handle_unknown='ignore'),text_cols_onehot),
    ('oe',OrdinalEncoder(),text_cols_ordinal),
    ('scaler',StandardScaler(),num_cols)
])

# %% [markdown]
# ### BASELINE MODEL -- TRAINING AND EVALUATION

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
modelLR = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('lr',LogisticRegression())
])
modelLR.fit(x_train,y_train)
predictionLR = modelLR.predict(x_test)

# %%
# result of logistic regression
from sklearn.metrics import (confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionLR)
acc_train = modelLR.score(x_train,y_train)
acc_test = modelLR.score(x_test,y_test)
p = precision_score(y_test,predictionLR)
r = recall_score(y_test,predictionLR)
f1 = f1_score(y_test,predictionLR)
roc = roc_auc_score(y_test,modelLR.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.571725
# test_accuracy score : 0.5666
# precision : 0.5757367589475854
# recall : 0.770808424537846
# f1 score : 0.6591427447896185
# roc auc score : 0.5847510070021554
# confusion matrix : [[2951 6176]
#  [2492 8381]]

# %%
joblib.dump(modelLR,'../Models/LogisticRegression_Baselinemodel.pkl')
# Out:
# ['../Models/LogisticRegression_Baselinemodel.pkl']

# %% [markdown]
# K Nearest Neighbors KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
modelKNN = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('knn',KNeighborsClassifier())
])
modelKNN.fit(x_train,y_train)
predictionKNN = modelKNN.predict(x_test)

# %%
# result of KNN
from sklearn.metrics import (confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionKNN)
acc_train = modelKNN.score(x_train,y_train)
acc_test = modelKNN.score(x_test,y_test)
p = precision_score(y_test,predictionKNN)
r = recall_score(y_test,predictionKNN)
f1 = f1_score(y_test,predictionKNN)
roc = roc_auc_score(y_test,modelKNN.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.698025
# test_accuracy score : 0.51855
# precision : 0.553126067646054
# recall : 0.5956037892026119
# f1 score : 0.5735795580355166
# roc auc score : 0.5142842040615723
# confusion matrix : [[3895 5232]
#  [4397 6476]]

# %%
joblib.dump(modelKNN,'../Models/KNN_Baselinemodel.pkl')
# Out:
# ['../Models/KNN_Baselinemodel.pkl']

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
modelDT = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('dt',DecisionTreeClassifier())
])
modelDT.fit(x_train,y_train)
predictionDT = modelDT.predict(x_test)

# %%
# result of Decision Tree
from sklearn.metrics import (confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionDT)
acc_train = modelDT.score(x_train,y_train)
acc_test = modelDT.score(x_test,y_test)
p = precision_score(y_test,predictionDT)
r = recall_score(y_test,predictionDT)
f1 = f1_score(y_test,predictionDT)
roc = roc_auc_score(y_test,modelDT.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 1.0
# test_accuracy score : 0.5121
# precision : 0.5510765002290426
# recall : 0.5532051871608572
# f1 score : 0.5521387919955939
# roc auc score : 0.5081682778140213
# confusion matrix : [[4227 4900]
#  [4858 6015]]

# %%
joblib.dump(modelDT,'../Models/DecisionTree_Baselinemodel.pkl')
# Out:
# ['../Models/DecisionTree_Baselinemodel.pkl']

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
modelRF = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('rf',RandomForestClassifier())
])
modelRF.fit(x_train,y_train)
predictionRF = modelRF.predict(x_test)

# %%
# result of Random Forest
from sklearn.metrics import (confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionRF)
acc_train = modelRF.score(x_train,y_train)
acc_test = modelRF.score(x_test,y_test)
p = precision_score(y_test,predictionRF)
r = recall_score(y_test,predictionRF)
f1 = f1_score(y_test,predictionRF)
roc = roc_auc_score(y_test,modelRF.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 1.0
# test_accuracy score : 0.5504
# precision : 0.5691289966923925
# recall : 0.7121309666145498
# f1 score : 0.6326497262848272
# roc auc score : 0.5551734428079377
# confusion matrix : [[3265 5862]
#  [3130 7743]]

# %%
joblib.dump(modelRF,'../Models/RandomForest_Baselinemodel.pkl')
# Out:
# ['../Models/RandomForest_Baselinemodel.pkl']

# %% [markdown]
# Support Vector Machine SVM

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
modelSVM = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('svm',SVC())
])
modelSVM.fit(x_train,y_train)
predictionSVM = modelSVM.predict(x_test)

# %%
# result of SVM
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionSVM)
acc_train = modelSVM.score(x_train,y_train)
acc_test = accuracy_score(y_test,predictionSVM)
p = precision_score(y_test,predictionSVM)
r = recall_score(y_test,predictionSVM)
f1 = f1_score(y_test,predictionSVM)
roc = roc_auc_score(y_test,modelSVM.decision_function(x_test))
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.6235
# test_accuracy score : 0.5638
# precision : 0.5695154299023096
# recall : 0.8096201600294307
# f1 score : 0.6686669198632739
# roc auc score : 0.569123807583498
# confusion matrix : [[2473 6654]
#  [2070 8803]]

# %%
joblib.dump(modelSVM,'../Models/SVM_Baselinemodel.pkl')
# Out:
# ['../Models/SVM_Baselinemodel.pkl']

# %% [markdown]
# Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.pipeline import Pipeline
modelNB = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('nb',GaussianNB())
])
modelNB.fit(x_train,y_train)
predictionNB = modelNB.predict(x_test)

# %%
# result of Naive Bayes
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionNB)
acc_train = accuracy_score(y_train,modelNB.predict(x_train))
acc_test = accuracy_score(y_test,predictionNB)
p = precision_score(y_test,predictionNB)
r = recall_score(y_test,predictionNB)
f1 = f1_score(y_test,predictionNB)
roc = roc_auc_score(y_test,modelNB.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.5700875
# test_accuracy score : 0.569
# precision : 0.576481770656528
# recall : 0.7809252276280695
# f1 score : 0.6633075540973361
# roc auc score : 0.5796064992164132
# confusion matrix : [[2889 6238]
#  [2382 8491]]

# %%
joblib.dump(modelNB,'../Models/NaiveBayes_Baselinemodel.pkl')
# Out:
# ['../Models/NaiveBayes_Baselinemodel.pkl']

# %% [markdown]
# XG Boost

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
modelXG = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('xgb',XGBClassifier())
])
modelXG.fit(x_train,y_train)
predictionXG = modelXG.predict(x_test)

# %%
# result of XG Boost
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionXG)
acc_train = accuracy_score(y_train,modelXG.predict(x_train))
acc_test = accuracy_score(y_test,predictionXG)
p = precision_score(y_test,predictionXG)
r = recall_score(y_test,predictionXG)
f1 = f1_score(y_test,predictionXG)
roc = roc_auc_score(y_test,modelXG.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.71905
# test_accuracy score : 0.54615
# precision : 0.5680509245225825
# recall : 0.6894141451301389
# f1 score : 0.6228758984585981
# roc auc score : 0.5538077998468951
# confusion matrix : [[3427 5700]
#  [3377 7496]]

# %%
joblib.dump(modelXG,'../Models/XGBoost_Baselinemodel.pkl')
# Out:
# ['../Models/XGBoost_Baselinemodel.pkl']

# %% [markdown]
# Voting

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
modelV = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('v',VotingClassifier(estimators=[
        ('lr',LogisticRegression()),
        ('knn',KNeighborsClassifier()),
        ('dt',DecisionTreeClassifier()),
        ('rf',RandomForestClassifier()),
        ('svm',SVC(probability=True)),
        ('nb',GaussianNB()),
        ('xg',XGBClassifier())
    ],voting='soft'))
])
modelV.fit(x_train,y_train)
predictionV = modelV.predict(x_test)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\svm\_base.py:239: FutureWarning: The `probability` parameter was deprecated in 1.9 and will be removed in version 1.11. Use `CalibratedClassifierCV(SVC(), ensemble=False)` instead of `SVC(probability=True)`
#   warnings.warn(

# %%
# result of Voting
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionV)
acc_train = accuracy_score(y_train,modelV.predict(x_train))
acc_test = accuracy_score(y_test,predictionV)
p = precision_score(y_test,predictionV)
r = recall_score(y_test,predictionV)
f1 = f1_score(y_test,predictionV)
roc = roc_auc_score(y_test, modelV.predict_proba(x_test)[:, 1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.98975
# test_accuracy score : 0.54465
# precision : 0.5680487053020962
# recall : 0.6779177779821577
# f1 score : 0.6181391253302025
# roc auc score : 0.5485884214505166
# confusion matrix : [[3522 5605]
#  [3502 7371]]

# %%
joblib.dump(modelV,'../Models/Voting_Baselinemodel.pkl')
# Out:
# ['../Models/Voting_Baselinemodel.pkl']

# %% [markdown]
# Stacking

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.pipeline import Pipeline
modelS = Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('s',StackingClassifier(estimators=[
        ('lr',LogisticRegression()),
        ('knn',KNeighborsClassifier()),
        ('dt',DecisionTreeClassifier()),
        ('rf',RandomForestClassifier()),
        ('svm',SVC()),
        ('nb',GaussianNB()),
        ('xg',XGBClassifier())
    ], final_estimator=LogisticRegression()))
])
modelS.fit(x_train,y_train)
predictionS = modelS.predict(x_test)

# %%
# result of Stacking
from sklearn.metrics import (accuracy_score,confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score)
cm = confusion_matrix(y_test,predictionS)
acc_train = accuracy_score(y_train,modelS.predict(x_train))
acc_test = accuracy_score(y_test,predictionS)
p = precision_score(y_test,predictionS)
r = recall_score(y_test,predictionS)
f1 = f1_score(y_test,predictionS)
roc = roc_auc_score(y_test,modelS.predict_proba(x_test)[:,1])
print("train_accuracy score :",acc_train)
print("test_accuracy score :",acc_test)
print("precision :",p)
print("recall :",r)
print("f1 score :",f1)
print("roc auc score :",roc)
print("confusion matrix :",cm)
# Out:
# train_accuracy score : 0.6154875
# test_accuracy score : 0.56855
# precision : 0.5767756945394827
# recall : 0.7752230295226709
# f1 score : 0.6614352414956645
# roc auc score : 0.5840597487223401
# confusion matrix : [[2942 6185]
#  [2444 8429]]

# %%
joblib.dump(modelS,'../Models/Stacking_Baselinemodel.pkl')
# Out:
# ['../Models/Stacking_Baselinemodel.pkl']

# %% [markdown]
# ### COMPARISION OF BASELINE MODELS

# %% [markdown]
# | Model | Train Accuracy | Test Accuracy | Precision | Recall | F1-Score | ROC-AUC | Overfitting | Selected |
# |-------|---------------:|--------------:|----------:|--------:|---------:|--------:|-------------|:--------:|
# | Logistic Regression | 57.17% | 56.66% | 0.576 | 0.771 | 0.659 | 0.585 | No | ✅ |
# | K-Nearest Neighbors (KNN) | 69.80% | 51.86% | 0.553 | 0.596 | 0.574 | 0.514 | Yes | ❌ |
# | Decision Tree | 100.00% | 51.21% | 0.551 | 0.553 | 0.552 | 0.508 | Severe | ❌ |
# | Random Forest | 100.00% | 55.04% | 0.569 | 0.712 | 0.633 | 0.555 | Moderate | ✅ |
# | Support Vector Machine (SVM) | 62.35% | 56.38% | 0.570 | 0.810 | 0.669 | 0.569 | No | ✅ |
# | Naive Bayes | 57.01% | 56.90% | 0.576 | 0.781 | 0.663 | 0.580 | No | ✅ |
# | XGBoost | 71.91% | 54.62% | 0.568 | 0.689 | 0.623 | 0.554 | Moderate | ❌ |
# | Voting Classifier | 98.98% | 54.47% | 0.568 | 0.678 | 0.618 | 0.549 | Severe | ❌ |
# | Stacking Classifier | 61.55% | 56.86% | 0.577 | 0.775 | 0.661 | 0.584 | No | ✅ |

# %% [markdown]
# Based on the baseline evaluation, Support Vector Machine (SVM) and Random Forest were selected for hyperparameter tuning due to their strong predictive performance and potential for further improvement.
