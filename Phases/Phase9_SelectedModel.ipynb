# %% [markdown]
# ### SELECTED MODEL

# %% [markdown]
# After evaluating multiple machine learning models and performing hyperparameter tuning, the tuned Random Forest Classifier achieved the best overall performance and was selected as the final model for house price prediction.
