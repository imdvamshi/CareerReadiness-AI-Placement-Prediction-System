# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../src/afterFeatureEngineering_data.csv")
data.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    linkedin_connections  mock_interview_score  attendance_percentage  \
# ...

# %%
x = data.drop(columns=['placement_status'])
x.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    github_repos  linkedin_connections  mock_interview_score  \
# 0             1                   184             72.647009
# ...

# %%
y = data['placement_status']
y.head()
# Out:
# 0    Not Placed
# 1    Not Placed
# 2        Placed
# 3    Not Placed
# 4        Placed
# Name: placement_status, dtype: str

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
# print("training set of x :",x_train)
# print("training set of y :",y_train)
# print("testing set of x :",x_test)
# print("testing set of y :",x_test)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (80000, 24)
# (20000, 24)
# (80000,)
# (20000,)

# %%
x_train.to_csv("../src/x_train.csv",index=False)
y_train.to_csv("../src/y_train.csv",index=False)
x_test.to_csv("../src/x_test.csv",index=False)
y_test.to_csv("../src/y_test.csv",index=False)
