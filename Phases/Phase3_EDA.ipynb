# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append("..")
from src.load_data import load_data
data = load_data()
data.head()
# Out:
#    student_id  age  gender  cgpa branch college_tier  internships_count  \
# 0           1   24    Male  7.53     IT       Tier 2                  4
# 1           2   21    Male  7.92    CSE       Tier 2                  1
# 2           3   22  Female  8.60    EEE       Tier 1                  0
# 3           4   24    Male  6.68    CSE       Tier 1                  0
# 4           5   20  Female  8.43     IT       Tier 3                  1
#
#    projects_count  certifications_count  coding_skill_score  ...  \
# 0               6                     1           99.238568  ...
# 1               3                     6           80.966123  ...
# 2               1                     1           49.177184  ...
# 3               2                     2           79.359084  ...
# 4               4                     3           65.018573  ...
#
#    mock_interview_score  attendance_percentage  backlogs  \
# 0             72.647009              77.463863         2
# ...

# %% [markdown]
# ### Exploratory Data Analysis
# 1. The dataset has students whose age fall between 18 to 24.<br></br>
# 2. Placement rates remain fairly consistent across different age groups, indicating little to no correlation between age and placement status.<br></br>
# 3. The dataset contains a higher proportion of male students (60.0%) compared to female students (40.0%), indicating a moderate gender imbalance in the dataset.<br></br>
# 4. Placement rates are comparable for both genders, indicating no strong correlation between gender and placement status.<br></br>
# 5. Most students have a CGPA around 7.5, indicating that the dataset is concentrated around average-to-high academic performance with few extreme values. The histogram dist has symmetric, bell-shaped stating the dataset is well distributed.<br></br>
# 6. Placed students generally have a marginally higher CGPA than non-placed students, suggesting that higher academic performance increases the likelihood of placement, though CGPA alone is not the sole deciding factor.<br></br>
# 7. Student distribution is uneven across branches, with CSE contributing the largest share, whereas EEE, Civil, and Mechanical have the lowest representation.<br></br>
# 8. CSE has the highest number of placed students, followed by IT and ECE, whereas Civil, EEE, and Mechanical have lower placement counts. Overall, placed students outnumber non-placed students in every branch.<br></br>
# 9. The dataset is dominated by Tier 2 colleges, with fewer students from Tier 3 and the least from Tier 1.<br></br>
# 10. Placement counts are highest for Tier 2 colleges, while Tier 1 has the lowest number of placed students because it has the smallest student population in the dataset.<br></br>
# 11. Internship experience ranges from 0 to 8, with the average student completing around 1–2 internships, suggesting moderate practical exposure across the dataset.<br></br>
# 12. Placed students have a marginally higher average internship count, indicating that completing more internships may improve placement chances.<br></br>
# 13. The number of projects completed ranges from 0 to 13, with the average student completing around 3 projects, reflecting a moderate level of hands-on project experience.<br></br>
# 14. Placed students have a slightly higher average project count, indicating that project experience may improve placement opportunities.<br></br>
# 15. Certification counts range from 0 to 11, with the average student completing about 2 certifications, indicating a moderate level of additional skill development.<br></br>
# 16. The average certification count is almost identical for placed and non-placed students, indicating a weak or negligible relationship between certification count and placement.<br></br>
# 17. Most students have moderate to high coding skill scores, while only a small proportion have very low scores. A cluster of perfect scores is also observed.<br></br>
# 18. Placed students exhibit a marginally higher average coding skill score, suggesting that coding proficiency contributes positively to placement outcomes.<br></br>
# 19. Most students have moderate to high aptitude scores, with the highest concentration around 65–70, while relatively few students have very low scores.<br></br>
# 20. Higher aptitude scores show only a weak positive association with placement, as both placed and non-placed students are distributed across similar score ranges.<br></br>
# 21. Most students possess moderate to strong communication skills, with the highest concentration around 65–70, while relatively few students have very low scores.<br></br>
# 22. Placed students demonstrate a marginally higher average communication score, suggesting that good communication skills contribute to placement success.<br></br>
# 23. Most students have moderate to high logical reasoning skills, with the highest concentration around 65–70, while only a few students have very low scores.<br></br>
# 24. Higher logical reasoning scores show only a weak positive association with placement, as both placed and non-placed students are distributed across similar score ranges.<br></br>
# 25. Hackathon participation is generally low, with the majority of students participating in one or fewer hackathons.<br></br>
# 26. Participating in more hackathons alone does not appear to significantly influence placement outcomes.<br></br>
# 27. The average student has around four GitHub repositories, while a few students have developed as many as 16 repositories.<br></br>
# 28. students with more GitHub repositories tend to have better placement outcomes, indicating that practical project experience shared on GitHub may improve employability.<br></br>
# 29. Students exhibit a wide range of LinkedIn connections, indicating varying levels of professional networking activity.<br></br>
# 30. The average number of LinkedIn connections is nearly the same for both placed and non-placed students, suggesting that networking alone has limited influence on placement.<br></br>
# 31. Most students have moderate to high mock interview scores, with the highest concentration around 70, indicating generally good interview performance across the dataset.<br></br>
# 32. Placed students have a marginally higher average mock interview score, indicating that interview performance contributes positively to placement success.<br></br>
# 33. Most students have high attendance percentages, with the majority scoring above 75%, while relatively few students have attendance below 60%.<br></br>
# 34. Higher attendance does not appear to guarantee placement, suggesting that attendance percentage has only a weak influence on placement outcomes.<br></br>
# 35. Backlog counts range from 0 to 6, with the average student having less than one backlog, suggesting generally good academic performance.<br></br>
# 36. Placed students generally have fewer backlogs than non-placed students, indicating that maintaining a good academic record improves placement chances.<br></br>
# 37. Most students have moderate extracurricular participation, while only a few have very low scores. A group of students also attained a perfect score of 100.<br></br>
# 38. Extracurricular participation appears to have only a weak association with placement outcomes, as students from both placement categories are distributed across similar score ranges.<br></br>
# 39. Most students have moderate leadership skills, while only a few have very low scores. A cluster of students also attained a perfect leadership score.<br></br>
# 40. Placed students exhibit a marginally higher average leadership score, indicating that leadership qualities may contribute to better placement opportunities.<br></br>
# 41. Nearly 60% of students have no volunteer experience, whereas about 40% have volunteered, showing a moderately imbalanced distribution.<br></br>
# 42. Volunteer experience alone does not appear to significantly influence placement outcomes, as both groups exhibit comparable placement patterns.<br></br>
# 43. The average student sleeps around 7 hours per day, with sleep durations ranging from 3 to 10 hours.<br></br>
# 44. Sleep duration appears to have little influence on placement outcomes, as both placed and non-placed students are observed across all sleep-hour ranges.<br></br>
# 45. The average student studies around 3.5 hours per day, with study durations ranging from 0.5 to 10 hours.<br></br>
# 46. Spending more time studying does not necessarily guarantee placement, indicating only a weak association between study hours and placement status.<br></br>
# 47. Placement patterns are similar across both genders, suggesting that gender has little influence on placement status. Bcz the dataset is recorded with more male records for placements showing a moderate imbalanced data.<br></br>
# 48. Most placed students receive salary packages in the range of 10–16 LPA, while the 0 LPA category corresponds to students without placement offers.<br></br>

# %% [markdown]
# 1. Distribution of age

# %%
sns.countplot(data=data,x='age')
plt.show()

# %% [markdown]
# 2. Does age affect the target value ( placed / not placed ) ?

# %%
data.groupby('age')['placement_status'].value_counts()
# Out:
# age  placement_status
# 18   Placed              7785
#      Not Placed          6444
# 19   Placed              7679
#      Not Placed          6645
# 20   Placed              7662
#      Not Placed          6371
# 21   Placed              7850
#      Not Placed          6556
# 22   Placed              7926
#      Not Placed          6460
# 23   Placed              7824
#      Not Placed          6486
# 24   Placed              7733
#      Not Placed          6579
# Name: count, dtype: int64

# %% [markdown]
# 3. Distribution of gender

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      60028
# Female    39972
# Name: count, dtype: int64

# %% [markdown]
# 4. Does gender affect the placement status?

# %%
data.groupby('gender')['placement_status'].value_counts()
# Out:
# gender  placement_status
# Female  Placed              21738
#         Not Placed          18234
# Male    Placed              32721
#         Not Placed          27307
# Name: count, dtype: int64

# %% [markdown]
# 5. Distribution of cgpa

# %%
sns.histplot(data=data,x='cgpa')
plt.show()

# %% [markdown]
# 6. Does cgpa has any link to placement status ?

# %%
sns.boxplot(data=data,x='placement_status',y='cgpa',hue='placement_status')
plt.show()

# %% [markdown]
# 7. Distribution of branch

# %%
sns.countplot(data=data,x='branch',hue='gender')
plt.show()

# %% [markdown]
# 8. Does branch/stream of the student affect placement status ?

# %%
data.groupby('branch')['placement_status'].value_counts()
# Out:
# branch      placement_status
# CSE         Placed              19026
#             Not Placed          15792
# Civil       Placed               5529
#             Not Placed           4492
# ECE         Placed               8066
#             Not Placed           6842
# EEE         Placed               5528
#             Not Placed           4649
# IT          Placed              10860
#             Not Placed           9139
# Mechanical  Placed               5450
#             Not Placed           4627
# Name: count, dtype: int64

# %% [markdown]
# 9. Distribution of college tier

# %%
data['college_tier'].value_counts()
# Out:
# college_tier
# Tier 2    49955
# Tier 3    29884
# Tier 1    20161
# Name: count, dtype: int64

# %% [markdown]
# 10. Does Tier of the college affect in placements ?

# %%
data.groupby('college_tier')['placement_status'].value_counts()
# Out:
# college_tier  placement_status
# Tier 1        Placed              10988
#               Not Placed           9173
# Tier 2        Placed              27118
#               Not Placed          22837
# Tier 3        Placed              16353
#               Not Placed          13531
# Name: count, dtype: int64

# %% [markdown]
# 11. What are the min, max and average internships done by the students

# %%
data['internships_count'].describe()
# Out:
# count    100000.00000
# mean          1.50223
# std           1.22528
# min           0.00000
# 25%           1.00000
# 50%           1.00000
# 75%           2.00000
# max           8.00000
# Name: internships_count, dtype: float64

# %% [markdown]
# 12. Does doing more internships give us job?

# %%
sns.barplot(data=data,x='placement_status',y='internships_count',hue='placement_status')
plt.show()

# %% [markdown]
# 13. What's the min, max, average projects done by the students ?

# %%
data['projects_count'].describe()
# Out:
# count    100000.000000
# mean          3.001860
# std           1.731764
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          13.000000
# Name: projects_count, dtype: float64

# %% [markdown]
# 14. Does the project count affet the placement status ?

# %%
sns.barplot(data=data,x='placement_status',y='projects_count',hue='placement_status')
plt.show()

# %% [markdown]
# 15. What's the min, max, average certifications done by the students ?

# %%
data['certifications_count'].describe()
# Out:
# count    100000.000000
# mean          2.005150
# std           1.416553
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          11.000000
# Name: certifications_count, dtype: float64

# %% [markdown]
# 16. Does doing more certifications help us in getting job ?

# %%
sns.barplot(data=data,x='placement_status',y='certifications_count',hue='placement_status')
plt.show()

# %% [markdown]
# 17. Distribution of coding skill score

# %%
sns.histplot(data=data,x='coding_skill_score')
plt.show()

# %% [markdown]
# 18. Does having more coding skill score help us get placed ?

# %%
sns.barplot(data=data,x='placement_status',y='coding_skill_score',hue='placement_status')
plt.show()

# %% [markdown]
# 19. Distribution of aptitude score

# %%
sns.histplot(data=data,x='aptitude_score')
plt.show()

# %% [markdown]
# 20. Does having more aptitude score help us get placed ?

# %%
data.groupby('aptitude_score')['placement_status'].value_counts()
# Out:
# aptitude_score  placement_status
# 20.000000       Placed               70
#                 Not Placed           67
# 20.008803       Not Placed            1
# 20.045309       Placed                1
# 20.086114       Not Placed            1
#                                    ...
# 99.980599       Placed                1
# 99.985846       Placed                1
# 99.999106       Not Placed            1
# 100.000000      Placed              603
#                 Not Placed          403
# Name: count, Length: 98861, dtype: int64

# %% [markdown]
# 21. Distribution of communication skill score

# %%
sns.histplot(data=data,x='communication_skill_score')
plt.show()

# %% [markdown]
# 22. Does communication skills help us get placed ?

# %%
sns.barplot(data=data,x='placement_status',y='communication_skill_score',hue='placement_status')
plt.show()

# %% [markdown]
# 23. Distribution of logical reasoning score

# %%
sns.histplot(data=data,x='logical_reasoning_score')
plt.show()

# %% [markdown]
# 24. Does logical reasoning skills help us in job ready ?

# %%
data.groupby('logical_reasoning_score')['placement_status'].value_counts()
# Out:
# logical_reasoning_score  placement_status
# 20.000000                Not Placed           59
#                          Placed               51
# 20.046936                Not Placed            1
# 20.100480                Not Placed            1
# 20.111014                Placed                1
#                                             ...
# 99.976493                Not Placed            1
# 99.976810                Placed                1
# 99.989009                Placed                1
# 100.000000               Placed              651
#                          Not Placed          511
# Name: count, Length: 98732, dtype: int64

# %% [markdown]
# 25. Distribution of hackthons participated

# %%
data['hackathons_participated'].value_counts()
# Out:
# hackathons_participated
# 1    36759
# 0    36722
# 2    18535
# 3     6096
# 4     1549
# 5      290
# 6       38
# 7       10
# 8        1
# Name: count, dtype: int64

# %% [markdown]
# 26. Does participating in hackathons help us get placed ?

# %%
sns.barplot(data=data,x='placement_status',y='hackathons_participated')
plt.show()

# %% [markdown]
# 27. What's the min, max, average github repos students hold ?

# %%
data['github_repos'].describe()
# Out:
# count    100000.000000
# mean          4.005160
# std           2.004897
# min           0.000000
# 25%           3.000000
# 50%           4.000000
# 75%           5.000000
# max          16.000000
# Name: github_repos, dtype: float64

# %% [markdown]
# 28. Does having more github repos help any how in getting placed ?

# %%
data.groupby('github_repos')['placement_status'].value_counts()
# Out:
# github_repos  placement_status
# 0             Placed               1004
#               Not Placed            831
# 1             Placed               3969
#               Not Placed           3349
# 2             Placed               7946
#               Not Placed           6805
# 3             Placed              10530
#               Not Placed           8795
# 4             Placed              10700
#               Not Placed           8876
# 5             Placed               8413
#               Not Placed           7082
# 6             Placed               5751
#               Not Placed           4766
# 7             Placed               3271
#               Not Placed           2744
# 8             Placed               1670
#               Not Placed           1335
# 9             Placed                733
#               Not Placed            586
# 10            Placed                318
#               Not Placed            245
# 11            Placed                121
# ...

# %% [markdown]
# 29. Distribution of linked in connections

# %%
sns.histplot(data=data,x='linkedin_connections')
plt.show()

# %% [markdown]
# 30. Does having more linkedin connections help us any how in getting placed ?

# %%
sns.barplot(data=data,x='placement_status',y='linkedin_connections',hue='placement_status')
plt.show()

# %% [markdown]
# 31. Distribution of mock interview score

# %%
sns.histplot(data=data,x='mock_interview_score')
plt.show()

# %% [markdown]
# 32. Does mock interview results decide placement status ?

# %%
sns.barplot(data=data,x='placement_status',y='mock_interview_score',hue='placement_status')
plt.show()

# %% [markdown]
# 33. Distribution of attendance percentage ?

# %%
sns.histplot(data=data,x='attendance_percentage')
plt.show()

# %% [markdown]
# 34. Does attendance percentage affect the placement status?

# %%
data.groupby('attendance_percentage')['placement_status'].value_counts()
# Out:
# attendance_percentage  placement_status
# 50.000000              Placed                12
#                        Not Placed             9
# 50.034473              Placed                 1
# 50.064736              Placed                 1
# 50.151364              Not Placed             1
#                                            ...
# 99.998586              Not Placed             1
# 99.999160              Placed                 1
# 99.999440              Placed                 1
# 100.000000             Placed              3582
#                        Not Placed          3002
# Name: count, Length: 93399, dtype: int64

# %% [markdown]
# 35. What's the min, max, average backlogs students having ?

# %%
data['backlogs'].describe()
# Out:
# count    100000.000000
# mean          0.497590
# std           0.708434
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max           6.000000
# Name: backlogs, dtype: float64

# %% [markdown]
# 36. Does having more backlogs affect getting in placed ?

# %%
sns.barplot(data=data,x='placement_status',y='backlogs')
plt.show()

# %% [markdown]
# 37. Distribution of Extra curricular score

# %%
sns.histplot(data=data,x='extracurricular_score')
plt.show()

# %% [markdown]
# 38. Does any how extra curricular score linked to placement status

# %%
data.groupby('extracurricular_score')['placement_status'].value_counts()
# Out:
# extracurricular_score  placement_status
# 0.000000               Not Placed            66
#                        Placed                65
# 0.018635               Not Placed             1
# 0.058317               Placed                 1
# 0.093774               Not Placed             1
#                                            ...
# 99.981055              Not Placed             1
# 99.990394              Placed                 1
# 99.999403              Placed                 1
# 100.000000             Placed              1255
#                        Not Placed           956
# Name: count, Length: 97662, dtype: int64

# %% [markdown]
# 39. Distribution of leadership score

# %%
sns.histplot(data=data,x='leadership_score')
plt.show()

# %% [markdown]
# 40. Does leadership skills help any way to get placed ?

# %%
sns.barplot(data=data,x='placement_status',y='leadership_score',hue='placement_status')
plt.show()

# %% [markdown]
# 41. Distribution of Volunteer Experience

# %%
data['volunteer_experience'].value_counts()
# Out:
# volunteer_experience
# No     59963
# Yes    40037
# Name: count, dtype: int64

# %% [markdown]
# 42. Does having volunteer experience help any way to get placed ?

# %%
data.groupby('volunteer_experience')['placement_status'].value_counts()
# Out:
# volunteer_experience  placement_status
# No                    Placed              32625
#                       Not Placed          27338
# Yes                   Placed              21834
#                       Not Placed          18203
# Name: count, dtype: int64

# %% [markdown]
# 43. What's the min, max , average sleep hours of student in dataset ?

# %%
data['sleep_hours'].describe()
# Out:
# count    100000.000000
# mean          6.983319
# std           1.468113
# min           3.000000
# 25%           6.000000
# 50%           7.000000
# 75%           8.000000
# max          10.000000
# Name: sleep_hours, dtype: float64

# %% [markdown]
# 44. Doees having less sleep hours help us get placed ?

# %%
data.groupby('sleep_hours')['placement_status'].value_counts()
# Out:
# sleep_hours  placement_status
# 3.0          Placed               269
#              Not Placed           194
# 3.1          Placed                43
#              Not Placed            38
# 3.2          Placed                69
#                                  ...
# 9.8          Not Placed           209
# 9.9          Placed               214
#              Not Placed           201
# 10.0         Placed              1370
#              Not Placed          1114
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# 45. What's the min, max, average study hours of student in the dataset ?

# %%
data['study_hours_per_day'].describe()
# Out:
# count    100000.000000
# mean          3.523124
# std           1.471248
# min           0.500000
# 25%           2.500000
# 50%           3.500000
# 75%           4.500000
# max          10.000000
# Name: study_hours_per_day, dtype: float64

# %% [markdown]
# 46. Does studying more hours helps us get placed ?

# %%
data.groupby('study_hours_per_day')['placement_status'].value_counts()
# Out:
# study_hours_per_day  placement_status
# 0.5                  Placed              1292
#                      Not Placed          1112
# 0.6                  Placed               236
#                      Not Placed           182
# 0.7                  Placed               254
#                                          ...
# 9.2                  Placed                 2
# 9.3                  Placed                 2
# 9.5                  Not Placed             2
# 9.6                  Placed                 1
# 10.0                 Placed                 2
# Name: count, Length: 177, dtype: int64

# %% [markdown]
# 47. Distribution of placement status

# %%
sns.countplot(data=data,x='placement_status',hue='gender')
plt.show()

# %% [markdown]
# 48. distribution of salary package in lpa

# %%
sns.histplot(data=data,x='salary_package_lpa')
plt.show()
